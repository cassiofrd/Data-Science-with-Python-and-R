# %% [markdown]
# # <font color='blue'>Data Science Academy - Visualização de Dados e Design de Dashboards</font>

# %% [markdown]
# ## ScatterPlot 3D e Plotly

# %%
from matplotlib import pyplot
# %matplotlib inline

# %%
# Range de 0 - 541
X = range(0, 541)

# Gera valores de y com base em valores de x usando list compreheension
Y = [i*i for i in X]

# Gera o gráfico
pyplot.plot(X, Y, '-')

# Labels e título
pyplot.title('Plotting x*x')
pyplot.xlabel('Eixo X')
pyplot.ylabel('Eixo Y')

# Salva o chart como png
pyplot.savefig('Simple.png')

# Mostra o gráfico
pyplot.show()

# %%
# Plot 3D
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.gca(projection='3d')

# Criando a curva do eixo z
x = np.linspace(0, 1, 100)
y = np.sin(x * -1 * np.pi) / 2 + 0.5

ax.plot(x, y, zs = 0, zdir = 'z', label = 'Curva randômica, apenas para o eixo z')

# Cores
colors = ('r', 'g', 'k', 'b')

for c in colors:
    x = np.random.sample(42)
    y = np.random.sample(42)
    ax.scatter(x, y, 1, zdir='x', c=c)

# Legenda
ax.legend()

# Eixos x, y e z
ax.set_xlim3d(0, 1)
ax.set_ylim3d(0, 1)
ax.set_zlim3d(0, 1)

# Mostra o chart
plt.show()

# %%
# Plotly
# Galeria: https://plot.ly/python/

# !pip install plotly

# Importa o plotly
import plotly
import plotly.plotly as py

# Importa todos os tipos de gráficos
from plotly.graph_objs import *

# Definindo API Key, credenciais e streaming como definido em https://plot.ly/python/getting-started
plotly.tools.set_credentials_file(username='xxx', 
                                  api_key = 'xxx', 
                                  stream_ids = ['[streamingkey1]', '[streamingkey2]'])

# Cria um dataset
trace0 = Scatter(
    x = [5, 10, 15, 20],
    y = [20, 40, 35, 16]
)

data = Data([trace0])

# Define a url e abre o gráfico no browser
unique_url = py.plot(data, filename = 'basic-line')
# Out:
# Requirement already satisfied: plotly in c:\anaconda3\lib\site-packages
# Requirement already satisfied: pytz in c:\anaconda3\lib\site-packages (from plotly)
# Requirement already satisfied: decorator>=4.0.6 in c:\anaconda3\lib\site-packages (from plotly)
# Requirement already satisfied: six in c:\anaconda3\lib\site-packages (from plotly)
# Requirement already satisfied: requests in c:\anaconda3\lib\site-packages (from plotly)
# Requirement already satisfied: nbformat>=4.2 in c:\anaconda3\lib\site-packages (from plotly)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\anaconda3\lib\site-packages (from requests->plotly)
# Requirement already satisfied: idna<2.7,>=2.5 in c:\anaconda3\lib\site-packages (from requests->plotly)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in c:\anaconda3\lib\site-packages (from requests->plotly)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\lib\site-packages (from requests->plotly)
# Requirement already satisfied: ipython_genutils in c:\anaconda3\lib\site-packages (from nbformat>=4.2->plotly)
# Requirement already satisfied: traitlets>=4.1 in c:\anaconda3\lib\site-packages (from nbformat>=4.2->plotly)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\anaconda3\lib\site-packages (from nbformat>=4.2->plotly)
# Requirement already satisfied: jupyter_core in c:\anaconda3\lib\site-packages (from nbformat>=4.2->plotly)
# You are using pip version 9.0.1, however version 10.0.0 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
unique_url
# Out:
# 'https://plot.ly/~gabriellimagomes15/6'

# %% [markdown]
# # Fim
